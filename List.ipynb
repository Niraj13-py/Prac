# %%
print ("MSI")
# Out:
# MSI

# %%
#List comprehension#

# %%
#Example [List] declartion#

# %%
#Silcing

# %%
#Mutable

# %%
#Iteratable

# %%
#List_Functions#
#append
#insert
#remove
#pop
#clear
#index
#count(values)
#sort
#reverse
#extend(iterable) we can use string#
#copy
