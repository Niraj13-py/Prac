# %%
#Imported Data structures
#1 Numpy Arrary
#2 DataFrames
#3 Series

# %%
import numpy  as np
A = np.array([10,20,30,40,50])
print(A)
# Out:
# [10 20 30 40 50]

# %%
A[-1]
# Out:
# 50

# %%
A[:3]
# Out:
# array([10, 20, 30])

# %%
A[0] = 60

# %%
for i in A: 
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
for i in range(5):
    print(A[i])
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
#image operations(NumPy)
import skimage.io as io
A = io.imread('Wallpaper.png', as_gray=True)
print(A.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 #image operations(NumPy)
# ----> 2 import skimage.io as io
#       3 A = io.imread('Wallpaper.png', as_gray=True)
#       4 print(A.shape)
#
# ModuleNotFoundError: No module named 'skimage'

# %%
#image operations(NumPy)
import skimage.io as io
A = io.imread('Wallpaper.png', as_gray=True)
print(A.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 #image operations(NumPy)
# ----> 2 import skimage.io as io
#       3 A = io.imread('Wallpaper.png', as_gray=True)
#       4 print(A.shape)
#
# ModuleNotFoundError: No module named 'skimage'

# %%
import skimage.io as io
A = io.imread('Wallpaper.png', as_gray=True)
print(A.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import skimage.io as io
#       2 A = io.imread('Wallpaper.png', as_gray=True)
#       3 print(A.shape)
#
# ModuleNotFoundError: No module named 'skimage'

# %%
import skimage.io as io
A = io.imread('Wallpaper.png', as_gray=True)    
print(A.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import skimage.io as io
#       2 A = io.imread('Wallpaper.png', as_gray=True)
#       3 print(A.shape)
#
# ModuleNotFoundError: No module named 'skimage'

# %%
import skimage.io as io
A = io.imread('Wallpaper.png', as_gray=True)    
print(A.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import skimage.io as io
#       2 A = io.imread('Wallpaper.png', as_gray=True)
#       3 print(A.shape)
#
# ModuleNotFoundError: No module named 'skimage'
