# %%
#Imported Data structures
#1 Numpy Arrary
#2 DataFrames
#3 Series

# %%
import numpy  as np
A = np.array([10,20,30,40,50])
print(A)
# Out:
# [10 20 30 40 50]

# %%
A[-1]
# Out:
# 50

# %%
A[:3]
# Out:
# array([10, 20, 30])

# %%
A[0] = 60

# %%
for i in A: 
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50
