# %%
print ("MSI")
# Out:
# MSI

# %%
#List comprehension#

# %%
#Example [List] declartion#

# %%
#Silcing

# %%
#Mutable

# %%
#Iteratable

# %%
#List_Functions#
#append
#insert
#remove
#pop
#clear
#index
#count(values)
#sort
#reverse
#extend(iterable) we can use string#
#copy

# %%
import skimageA = io.imread('Wallpaper.png', as_gray=True)
io.imshow(A)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import skimage
#
# ModuleNotFoundError: No module named 'skimage'

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open('Wallpaper.png')
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 from PIL import Image
#       2 import matplotlib.pyplot as plt
# ----> 4 img = Image.open('Wallpaper.png')
#       5 plt.imshow(img)
#       6 plt.axis('off')
#
# File c:\Users\niraj\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:3131, in open(fp, mode, formats)
#    3128     filename = fp
#    3130 if filename:
# -> 3131     fp = builtins.open(filename, "rb")
#    3132     exclusive_fp = True
#    3134 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Wallpaper.png'
