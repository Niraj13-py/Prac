# %%
#Tuples
#Indexing is there
#silcing t1[:2](all before 2)

# %%
#Immutable 
#Iterable

# %%
#Functions of Tuples
#Index
#Count

# %%
t1= (0,5,6,8,3)

print(t1[2])
# Out:
# 6

# %%
print(t1[:2])
# Out:
# (0, 5)

# %%
t1.count(4)
# Out:
# 0

# %%
t2 = (10)
type(t2)
# Out:
# int

# %%
B= [10]
type(B)
# Out:
# list

# %%
def add(*A):
    print(A)

# %%
add()
# Out:
# ()

# %%
def add(a,b,c):
    return a+b+c

# %%
add(10,20,40)
# Out:
# 70

# %%
def add(*A):
    total= 0
    for i in A:
        total= total = i
        return total

# %%
add()
