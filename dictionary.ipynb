# %%
d1 = {'A':10,'B':3.14,120:'pune'}

# %%
len(d1)
# Out:
# 3

# %%
d1['A']
# Out:
# 10

# %%
d1[120]
# Out:
# 'pune'

# %%
for i in d1:
    print(i)
# Out:
# A
# B
# 120

# %%
for i in d1:
    print(d1[i])
# Out:
# 10
# 3.14
# pune

# %%
population = {'Pune':50,'Mumbai ':200,'Nagpur':20,'Delhi' :190}

# %%
population['Delhi']
# Out:
# 190

# %%
# Find total Population
# Find minimum populaion and City name  =>20 Nagpur
# Avg Population

# %%
total_population =sum(population.values())
print("Total Population:", total_population)
# Out:
# Total Population: 460

# %%
MIN = population['pune']
min_city
# Out:
# 20

# %%
average_population = total_population / len(population)
print("Average Population:", average_population)
# Out:
# Average Population: 115.0

# %%
students = [{'Name':'Anup','Marks':22,'city':'pune'},
            {'Name':'Anil','Marks':82,'city':'Mumbai'},
            {'Name':'Anagha','Marks':63,'city':'pune'},
            {'Name':'Anay','Marks':75,'city':'Mumbai'}]

# %%
#Find total marks of all students
# Find avg marks of students from 'pune'
# print names of students who got pass (passing>=75)=> Anil Anay

# %%
students[0]['city']
# Out:
# 'pune'

# %%
for student in students:
    print(student['Marks'])
# Out:
# 22
# 82
# 63
# 75

# %%
total = 0
for student in students:
    total=total+student['Marks']
total
# Out:
# 242

# %%
total = 0
cnt = 0
for i in students:
    if i['city']=='pune':
        total = total + i['Marks']
        cnt = cnt+1
total/cnt
# Out:
# 42.5

# %%
for student in students:
    if student['Marks'] >= 75:
        print(student['Name'])
# Out:
# Anil
# Anay

# %%
d1 = {'A':10,'B':20,'C':30,'D':40}

# %%
d1['E'] = 50

# %%
d1
# Out:
# {'A': 10, 'B': 20, 'C': 30, 'D': 40, 'E': 50}

# %%
d1.keys()
# Out:
# dict_keys(['A', 'B', 'C', 'D', 'E'])

# %%
d1.values()
# Out:
# dict_values([10, 20, 30, 40, 50])

# %%
d1.items()
# Out:
# dict_items([('A', 10), ('B', 20), ('C', 30), ('D', 40), ('E', 50)])

# %%
for key, value in d1.items():
    print(key,value)
# Out:
# A 10
# B 20
# C 30
# D 40
# E 50

# %%
#5/06/2025
#Functions
d1.pop('D')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #5/06/2025
#       2 #Functions
# ----> 3 d1.pop('D')
#
# NameError: name 'd1' is not defined

# %%
d1 = {'A':10, 'B':200, 'C':50}
d2 = {'X':100, 'Y':200, 'Z':500}

d1.update(d2)

# %%
len(d1)
# Out:
# 6

# %%
print('d2')
# Out:
# d2

# %%
d1
# Out:
# {'A': 10, 'B': 200, 'C': 50, 'X': 100, 'Y': 200, 'Z': 500}

# %%
d2
# Out:
# {'X': 100, 'Y': 200, 'Z': 500}

# %%
#FROMKEYS
dict.fromkeys(['Pune', 'Mumbai', 'Nagpur'], 0)#to initialize dict

# TO print keys of a dictionary
# Out:
# {'Pune': 0, 'Mumbai': 0, 'Nagpur': 0}

# %%
k = ['Pune', 'Mumbai', 'Nagpur']
v= [10,20,30]
dict(zip(k,v))
# Out:
# {'Pune': 10, 'Mumbai': 20, 'Nagpur': 30}

# %%
#FROMKEyS => used to create new dict
dict.fromkeys(['A','B','C'], [1,2,3])
# Out:
# {'A': [1, 2, 3], 'B': [1, 2, 3], 'C': [1, 2, 3]}

# %%
#getfuncion, setdeFAULT  
#get = to access value , setdefault = to access value and add if key not present, to key

# %%
#get function example
students = [{'Name':'Anup','Marks':22,'city':'pune'},
            {'Name':'Anil','Marks':82,'city':'Mumbai'},
            {'Name':'Anagha','Marks':63,'city':'pune'},
            {'Name':'Anay','Marks':75,'city':'Mumbai'}]

# %%
#for every_student in students:
    #print([])

# %%
for student in students:
    print(student.get('Marks',0))
# Out:
# 22
# 82
# 63
# 75

# %%
#setdefault Function
d1 = {'A':10, 'B':20}
Y= d1.setdefault ('C',30)

# %%
d1
# Out:
# {'A': 10, 'B': 20, 'C': 30}

# %%
d1= {'A':10, 'B':20, 'C':30}

# %%
Y = d1.setdefault('B',40)
Y
# Out:
# 20

# %%
print(Y)
# Out:
# 20

# %%
d1
# Out:
# {'A': 10, 'B': 20, 'C': 30}

# %%
Y
# Out:
# 20

# %%
students = [{'Name':'Anup','Marks':22,'city':'pune'},
            {'Name':'Anil','Marks':82,'city':'Mumbai'},
            {'Name':'Anagha','Marks':63,'city':'pune'},
            {'Name':'Anay','Marks':75,'city':'Mumbai'}]#
